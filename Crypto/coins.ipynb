# %%
import pandas
import datetime
from matplotlib import pyplot as plt

# %%
df = pandas.read_csv('crypto_datasets/polygon.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close      Volume Currency
# 0  2019-06-27  0.018  0.022  0.017  0.019  1564289792      USD
# 1  2019-06-28  0.019  0.021  0.019  0.019   929598144      USD
# 2  2019-06-29  0.019  0.027  0.019  0.024  1788176128      USD
# 3  2019-06-30  0.024  0.027  0.022  0.022  1522535296      USD
# 4  2019-07-01  0.022  0.023  0.020  0.022   974462528      USD

# %%
plt.bar([date for date in df['Date']], [volume for volume in df['Volume']])
plt.xticks(rotation=45 )
plt.show()

# %%
df['Date'] = pandas.to_datetime(df['Date'], format="%Y-%m-%d")

# %%
df_2019 = df.loc[df['Date'].dt.year == 2019]
df_2019.head()
# Out:
#         Date   Open   High    Low  Close      Volume Currency
# 0 2019-06-27  0.018  0.022  0.017  0.019  1564289792      USD
# 1 2019-06-28  0.019  0.021  0.019  0.019   929598144      USD
# 2 2019-06-29  0.019  0.027  0.019  0.024  1788176128      USD
# 3 2019-06-30  0.024  0.027  0.022  0.022  1522535296      USD
# 4 2019-07-01  0.022  0.023  0.020  0.022   974462528      USD

# %%
date_list = [date for date in df_2019['Date']]
volume_list = [volume for volume in df_2019['Volume']]

# %%
max_volume = df_2019.loc[df_2019['Volume'] == df_2019['Volume'].max()]
max_volume
# Out:
#           Date   Open   High    Low  Close      Volume Currency
# 166 2019-12-10  0.034  0.035  0.011  0.017  6204859904      USD

# %%
df_2019.iloc[[165, 166, 167]]
# Out:
#           Date   Open   High    Low  Close      Volume Currency
# 165 2019-12-09  0.042  0.043  0.034  0.034   657008576      USD
# 166 2019-12-10  0.034  0.035  0.011  0.017  6204859904      USD
# 167 2019-12-11  0.017  0.020  0.017  0.018  1443623936      USD

# %%
min_volume = df_2019.loc[df_2019['Volume'] == df_2019['Volume'].min()]
min_volume
# Out:
#          Date   Open   High    Low  Close    Volume Currency
# 33 2019-07-30  0.011  0.012  0.011  0.012  76110464      USD

# %%
df_2019.iloc[[32, 33, 34]]
# Out:
#          Date   Open   High    Low  Close     Volume Currency
# 32 2019-07-29  0.012  0.012  0.011  0.011   89291312      USD
# 33 2019-07-30  0.011  0.012  0.011  0.012   76110464      USD
# 34 2019-07-31  0.012  0.012  0.011  0.011  147887280      USD
